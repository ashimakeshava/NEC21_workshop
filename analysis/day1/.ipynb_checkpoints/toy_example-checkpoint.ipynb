# %% [markdown]
# # Exploring Eye Tracking Data with a Toy Example

# %% [markdown]
# ## Import Statements

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import json

# %% [markdown]
# ## Read the JSON file

# %%
filename = 'toy_data_5.json'
with open(filename, 'r') as j:
    tmp = json.loads(j.read())
    samples_df = pd.json_normalize(data=tmp, sep='_',)
    
samples_df = pd.concat(
    [samples_df.drop(columns=['hitInfos']), 
     pd.concat([pd.json_normalize(row, sep='_',) for row in samples_df['hitInfos']], ignore_index=True)
    ], 
    axis=1
)

samples_df['timestamp'] = pd.to_datetime(samples_df.timestamp, utc=True, unit='s', origin='unix')
samples_df.set_index('timestamp', inplace=True)

samples_df.head()
# Out:
#                                      leftValidityMask  \
# timestamp
# 2021-09-11 00:36:11.849033472+00:00                31
# 2021-09-11 00:36:11.861454848+00:00                31
# 2021-09-11 00:36:11.869997056+00:00                31
# 2021-09-11 00:36:11.878981632+00:00                31
# 2021-09-11 00:36:11.887991808+00:00                31
#
#                                      leftDataGazeOriginValidity  \
# timestamp
# 2021-09-11 00:36:11.849033472+00:00                        True
# 2021-09-11 00:36:11.861454848+00:00                        True
# 2021-09-11 00:36:11.869997056+00:00                        True
# 2021-09-11 00:36:11.878981632+00:00                        True
# 2021-09-11 00:36:11.887991808+00:00                        True
#
#                                      leftDataGazeDirectionValidity  \
# timestamp
# 2021-09-11 00:36:11.849033472+00:00                           True
# 2021-09-11 00:36:11.861454848+00:00                           True
# 2021-09-11 00:36:11.869997056+00:00                           True
# 2021-09-11 00:36:11.878981632+00:00                           True
# 2021-09-11 00:36:11.887991808+00:00                           True
#
#                                      leftDataPupilDiameterValidity  \
# timestamp
# 2021-09-11 00:36:11.849033472+00:00                           True
# 2021-09-11 00:36:11.861454848+00:00                           True
# 2021-09-11 00:36:11.869997056+00:00                           True
# 2021-09-11 00:36:11.878981632+00:00                           True
# 2021-09-11 00:36:11.887991808+00:00                           True
#
#                                      leftDataEyeOpennessValidity  \
# timestamp
# 2021-09-11 00:36:11.849033472+00:00                         True
# 2021-09-11 00:36:11.861454848+00:00                         True
# 2021-09-11 00:36:11.869997056+00:00                         True
# 2021-09-11 00:36:11.878981632+00:00                         True
# 2021-09-11 00:36:11.887991808+00:00                         True
#
#                                      leftDataPupilPositionInSensorAreaValidity  \
# timestamp
# 2021-09-11 00:36:11.849033472+00:00                                       True
# 2021-09-11 00:36:11.861454848+00:00                                       True
# 2021-09-11 00:36:11.869997056+00:00                                       True
# 2021-09-11 00:36:11.878981632+00:00                                       True
# 2021-09-11 00:36:11.887991808+00:00                                       True
#
#                                      rightValidityMask  \
# timestamp
# 2021-09-11 00:36:11.849033472+00:00                 31
# 2021-09-11 00:36:11.861454848+00:00                 31
# 2021-09-11 00:36:11.869997056+00:00                 31
# 2021-09-11 00:36:11.878981632+00:00                 31
# 2021-09-11 00:36:11.887991808+00:00                 31
#
#                                      rightDataGazeOriginValidity  \
# timestamp
# 2021-09-11 00:36:11.849033472+00:00                         True
# 2021-09-11 00:36:11.861454848+00:00                         True
# 2021-09-11 00:36:11.869997056+00:00                         True
# 2021-09-11 00:36:11.878981632+00:00                         True
# 2021-09-11 00:36:11.887991808+00:00                         True
#
#                                      rightDataGazeDirectionValidity  \
# timestamp
# 2021-09-11 00:36:11.849033472+00:00                            True
# 2021-09-11 00:36:11.861454848+00:00                            True
# 2021-09-11 00:36:11.869997056+00:00                            True
# 2021-09-11 00:36:11.878981632+00:00                            True
# 2021-09-11 00:36:11.887991808+00:00                            True
#
#                                      rightDataPupilDiameterValidity  ...  \
# timestamp                                                            ...
# 2021-09-11 00:36:11.849033472+00:00                            True  ...
# 2021-09-11 00:36:11.861454848+00:00                            True  ...
# 2021-09-11 00:36:11.869997056+00:00                            True  ...
# 2021-09-11 00:36:11.878981632+00:00                            True  ...
# 2021-09-11 00:36:11.887991808+00:00                            True  ...
#
#                                      EyeDirectionCombinedWorld_x  \
# timestamp
# 2021-09-11 00:36:11.849033472+00:00                     0.316221
# 2021-09-11 00:36:11.861454848+00:00                     0.316693
# 2021-09-11 00:36:11.869997056+00:00                     0.317304
# 2021-09-11 00:36:11.878981632+00:00                     0.316552
# 2021-09-11 00:36:11.887991808+00:00                     0.314961
#
#                                      EyeDirectionCombinedWorld_y  \
# timestamp
# 2021-09-11 00:36:11.849033472+00:00                    -0.353435
# 2021-09-11 00:36:11.861454848+00:00                    -0.352962
# 2021-09-11 00:36:11.869997056+00:00                    -0.350035
# 2021-09-11 00:36:11.878981632+00:00                    -0.350531
# 2021-09-11 00:36:11.887991808+00:00                    -0.350752
#
#                                      EyeDirectionCombinedWorld_z  \
# timestamp
# 2021-09-11 00:36:11.849033472+00:00                     0.880375
# 2021-09-11 00:36:11.861454848+00:00                     0.880402
# 2021-09-11 00:36:11.869997056+00:00                     0.881345
# 2021-09-11 00:36:11.878981632+00:00                     0.881421
# 2021-09-11 00:36:11.887991808+00:00                     0.881898
#
#                                      singleHitInfo_hitPosition_x  \
# timestamp
# 2021-09-11 00:36:11.849033472+00:00                    -1.896670
# 2021-09-11 00:36:11.861454848+00:00                    -1.884416
# 2021-09-11 00:36:11.869997056+00:00                    -1.850652
# 2021-09-11 00:36:11.878981632+00:00                    -1.856269
# 2021-09-11 00:36:11.887991808+00:00                    -1.866096
#
#                                      singleHitInfo_hitPosition_y  \
# timestamp
# 2021-09-11 00:36:11.849033472+00:00                -2.390609e-16
# 2021-09-11 00:36:11.861454848+00:00                -2.392218e-16
# 2021-09-11 00:36:11.869997056+00:00                -2.403248e-16
# 2021-09-11 00:36:11.878981632+00:00                -2.401659e-16
# 2021-09-11 00:36:11.887991808+00:00                -2.401535e-16
#
#                                      singleHitInfo_hitPosition_z  \
# timestamp
# 2021-09-11 00:36:11.849033472+00:00                     7.936346
# 2021-09-11 00:36:11.861454848+00:00                     7.943593
# 2021-09-11 00:36:11.869997056+00:00                     7.993265
# 2021-09-11 00:36:11.878981632+00:00                     7.986111
# 2021-09-11 00:36:11.887991808+00:00                     7.985551
#
#                                      singleHitInfo_ObjectPosition_x  \
# timestamp
# 2021-09-11 00:36:11.849033472+00:00                             0.0
# 2021-09-11 00:36:11.861454848+00:00                             0.0
# 2021-09-11 00:36:11.869997056+00:00                             0.0
# 2021-09-11 00:36:11.878981632+00:00                             0.0
# 2021-09-11 00:36:11.887991808+00:00                             0.0
#
#                                      singleHitInfo_ObjectPosition_y  \
# timestamp
# 2021-09-11 00:36:11.849033472+00:00                   -2.220446e-16
# 2021-09-11 00:36:11.861454848+00:00                   -2.220446e-16
# 2021-09-11 00:36:11.869997056+00:00                   -2.220446e-16
# 2021-09-11 00:36:11.878981632+00:00                   -2.220446e-16
# 2021-09-11 00:36:11.887991808+00:00                   -2.220446e-16
#
#                                      singleHitInfo_ObjectPosition_z  \
# timestamp
# 2021-09-11 00:36:11.849033472+00:00                            7.17
# 2021-09-11 00:36:11.861454848+00:00                            7.17
# 2021-09-11 00:36:11.869997056+00:00                            7.17
# 2021-09-11 00:36:11.878981632+00:00                            7.17
# 2021-09-11 00:36:11.887991808+00:00                            7.17
#
#                                      singleHitInfo_ObjectName
# timestamp
# 2021-09-11 00:36:11.849033472+00:00              Orange Floor
# 2021-09-11 00:36:11.861454848+00:00              Orange Floor
# 2021-09-11 00:36:11.869997056+00:00              Orange Floor
# 2021-09-11 00:36:11.878981632+00:00              Orange Floor
# 2021-09-11 00:36:11.887991808+00:00              Orange Floor
#
# [5 rows x 68 columns]

# %% [markdown]
# ## Check Data types

# %%
samples_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 9524 entries, 2021-09-11 00:36:11.849033472+00:00 to 2021-09-11 00:37:57.608784896+00:00
# Data columns (total 68 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   leftValidityMask                            9524 non-null   int64
#  1   leftDataGazeOriginValidity                  9524 non-null   bool
#  2   leftDataGazeDirectionValidity               9524 non-null   bool
#  3   leftDataPupilDiameterValidity               9524 non-null   bool
#  4   leftDataEyeOpennessValidity                 9524 non-null   bool
#  5   leftDataPupilPositionInSensorAreaValidity   9524 non-null   bool
#  6   rightValidityMask                           9524 non-null   int64
#  7   rightDataGazeOriginValidity                 9524 non-null   bool
#  8   rightDataGazeDirectionValidity              9524 non-null   bool
#  9   rightDataPupilDiameterValidity              9524 non-null   bool
#  10  rightDataEyeOpennessValidity                9524 non-null   bool
#  11  rightDataPupilPositionInSensorAreaValidity  9524 non-null   bool
#  12  eyeOpennessLeft                             9524 non-null   float64
#  13  eyePupilDiameterLeft                        9524 non-null   float64
#  14  eyeOpennessRight                            9524 non-null   float64
#  15  eyePupilDiameterRight                       9524 non-null   float64
#  16  hmdPosition_x                               9524 non-null   float64
#  17  hmdPosition_y                               9524 non-null   float64
#  18  hmdPosition_z                               9524 non-null   float64
#  19  hmdRotation_x                               9524 non-null   float64
#  20  hmdRotation_y                               9524 non-null   float64
#  21  hmdRotation_z                               9524 non-null   float64
#  22  noseVector_x                                9524 non-null   float64
#  23  noseVector_y                                9524 non-null   float64
#  24  noseVector_z                                9524 non-null   float64
#  25  eyePositionLeftLocal_x                      9524 non-null   float64
#  26  eyePositionLeftLocal_y                      9524 non-null   float64
#  27  eyePositionLeftLocal_z                      9524 non-null   float64
#  28  eyeDirectionLeftLocal_x                     9524 non-null   float64
#  29  eyeDirectionLeftLocal_y                     9524 non-null   float64
#  30  eyeDirectionLeftLocal_z                     9524 non-null   float64
#  31  eyePositionLeftWorld_x                      9524 non-null   float64
#  32  eyePositionLeftWorld_y                      9524 non-null   float64
#  33  eyePositionLeftWorld_z                      9524 non-null   float64
#  34  eyeDirectionLeftWorld_x                     9524 non-null   float64
#  35  eyeDirectionLeftWorld_y                     9524 non-null   float64
#  36  eyeDirectionLeftWorld_z                     9524 non-null   float64
#  37  eyePositionRightLocal_x                     9524 non-null   float64
#  38  eyePositionRightLocal_y                     9524 non-null   float64
#  39  eyePositionRightLocal_z                     9524 non-null   float64
#  40  eyeDirectionRightLocal_x                    9524 non-null   float64
#  41  eyeDirectionRightLocal_y                    9524 non-null   float64
#  42  eyeDirectionRightLocal_z                    9524 non-null   float64
#  43  eyePositionRightWorld_x                     9524 non-null   float64
#  44  eyePositionRightWorld_y                     9524 non-null   float64
#  45  eyePositionRightWorld_z                     9524 non-null   float64
#  46  eyeDirectionRightWorld_x                    9524 non-null   float64
#  47  eyeDirectionRightWorld_y                    9524 non-null   float64
#  48  eyeDirectionRightWorld_z                    9524 non-null   float64
#  49  EyePositionCombinedLocal_x                  9524 non-null   float64
#  50  EyePositionCombinedLocal_y                  9524 non-null   float64
#  51  EyePositionCombinedLocal_z                  9524 non-null   float64
#  52  EyeDirectionCombinedLocal_x                 9524 non-null   float64
#  53  EyeDirectionCombinedLocal_y                 9524 non-null   float64
#  54  EyeDirectionCombinedLocal_z                 9524 non-null   float64
#  55  EyePositionCombinedWorld_x                  9524 non-null   float64
#  56  EyePositionCombinedWorld_y                  9524 non-null   float64
#  57  EyePositionCombinedWorld_z                  9524 non-null   float64
#  58  EyeDirectionCombinedWorld_x                 9524 non-null   float64
#  59  EyeDirectionCombinedWorld_y                 9524 non-null   float64
#  60  EyeDirectionCombinedWorld_z                 9524 non-null   float64
#  61  singleHitInfo_hitPosition_x                 9524 non-null   float64
#  62  singleHitInfo_hitPosition_y                 9524 non-null   float64
#  63  singleHitInfo_hitPosition_z                 9524 non-null   float64
#  64  singleHitInfo_ObjectPosition_x              9524 non-null   float64
#  65  singleHitInfo_ObjectPosition_y              9524 non-null   float64
#  66  singleHitInfo_ObjectPosition_z              9524 non-null   float64
#  67  singleHitInfo_ObjectName                    9524 non-null   object
# dtypes: bool(10), float64(55), int64(2), object(1)
# memory usage: 4.4+ MB

# %% [markdown]
# ## Start Plotting!

# %%
# Create dict for staircase Plot
obj_dict = dict(zip(samples_df.singleHitInfo_ObjectName.unique(), np.arange(samples_df.singleHitInfo_ObjectName.nunique())))
obj_dict
# Out:
# {'Orange Floor': 0,
#  'Cube': 1,
#  'Pole': 2,
#  'Rail (3)': 3,
#  'Rail (6)': 4,
#  'GreenFloor': 5,
#  'Blue Capsule': 6,
#  'Black Cylinder': 7,
#  'Blue Floor': 8,
#  'Blue Wall': 9,
#  'Rail': 10,
#  'Red Wall': 11,
#  'Red Capsule': 12,
#  'GreenCube': 13,
#  'Rail (4)': 14,
#  'RedFloor': 15,
#  'Red Cube': 16,
#  'Rail (5)': 17,
#  'Platform': 18,
#  'Orange Wall': 19,
#  'Green Wall': 20,
#  'Blue Sphere': 21,
#  'Blue Cylinder': 22,
#  'Glas': 23,
#  'Green Sphere': 24,
#  'Rail (2)': 25,
#  'OrangeCube': 26,
#  'Orange Sphere': 27,
#  'Rail (1)': 28,
#  'Rail (7)': 29}

# %%
## Choose only valid samples
tmpdf = (
    samples_df
    .query('leftValidityMask == 31 and rightValidityMask == 31')
)

tmpdf['obj_id'] = tmpdf.singleHitInfo_ObjectName.map(obj_dict)


sns.set(context = "talk", style="whitegrid", palette="muted", font_scale=1, rc={'figure.figsize':(11.7,8.27)})
_, ax = plt.subplots(figsize=(25,10))

ax.scatter(tmpdf.index, tmpdf['obj_id'], label='rayhit', marker='o')

ax.legend()
ax.set(
    yticks=list(obj_dict.values()),
    yticklabels=obj_dict.keys(),
    ylabel='Hit Objects',
    xlabel='timestamp'
);
# Out:
# <ipython-input-7-9edf932a4af5>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tmpdf['obj_id'] = tmpdf.singleHitInfo_ObjectName.map(obj_dict)

# %%
_, ax = plt.subplots(figsize=(25,10))

ax = sns.countplot(data=samples_df, x='singleHitInfo_ObjectName', palette='Set1')
ax.set(
    xlabel='Hit Objects',
    ylabel='Frequency'
)
plt.xticks(rotation=45);

# %%
samples_df['theta_h'] = np.arctan2(samples_df.EyeDirectionCombinedWorld_x, samples_df.EyeDirectionCombinedWorld_z)
samples_df['theta_v'] = np.arctan2(samples_df.EyeDirectionCombinedWorld_y, samples_df.EyeDirectionCombinedWorld_z)

samples_df['time'] = samples_df.index
samples_df['time_delta'] = samples_df.time - samples_df.time.shift()
samples_df['time_delta'] = samples_df.time_delta.apply(lambda x: x/np.timedelta64(1,'s'))

samples_df['eye_velocity_h'] = samples_df.theta_h.diff()/samples_df.time_delta
samples_df['eye_velocity_v'] = samples_df.theta_v.diff()/samples_df.time_delta

samples_df['eye_velocity_mag'] = np.sqrt(samples_df.eye_velocity_h**2 + samples_df.eye_velocity_v**2 )

# %%
samples_df['head_theta_h'] = np.arctan2(samples_df.noseVector_x, samples_df.noseVector_z)
samples_df['head_theta_v'] = np.arctan2(samples_df.noseVector_y, samples_df.noseVector_z)

samples_df['head_velocity_h'] = samples_df.head_theta_h.diff()/samples_df.time_delta
samples_df['head_velocity_v'] = samples_df.head_theta_v.diff()/samples_df.time_delta

samples_df['head_velocity_mag'] = np.sqrt(samples_df.head_velocity_h**2 + samples_df.head_velocity_v**2 )

# %%
_, ax = plt.subplots(figsize=(20,10))

ax.scatter(samples_df.index, samples_df.time_delta, label='time difference')
# ax.plot(samples_df.index, samples_df.eye_velocity_h, color='r', )
# ax.plot(samples_df.index, samples_df.eye_velocity_v, color='g', )

ax.legend()
ax.set(
    ylim=(0,0.02),
    xlabel='timestamp',
    ylabel='Difference between time samples (s)'
);

# %%
_, ax = plt.subplots(figsize=(20,10))

ax.scatter(samples_df.index, samples_df.eye_velocity_mag, label='all data', color='b', s=100)

tmpdf = (
    samples_df
    .query('leftValidityMask == 31 and rightValidityMask == 31')
)
ax.scatter(tmpdf.index, tmpdf.eye_velocity_mag, label='valid eye velocity', color='g', alpha=0.4, s=100)

ax.scatter(tmpdf.index, tmpdf.head_velocity_mag, label='valid head velocity', color='r', alpha=0.4, s=100)

# ax.plot(samples_df.index, samples_df.eye_velocity_h, color='r', )
# ax.plot(samples_df.index, samples_df.eye_velocity_v, color='g', )

ax.legend()
ax.set(
    xlabel='timestamp',
    ylabel=r'Velocity ($\degree$/s)'
);

# %%
np.mean(1/samples_df.time_delta)
# Out:
# 90.22250753590735

# %%
(samples_df.index[-1] - samples_df.index[0])/np.timedelta64(1, 's')
# Out:
# 105.759751424

# %%
"{0:b}".format(31)
